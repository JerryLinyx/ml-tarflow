# %%
import kagglehub

path = kagglehub.dataset_download("dimensi0n/afhq-512")
print(path)
# Out:
# ...
# 100%|██████████| 6.48G/6.48G [03:01<00:00, 38.2MB/s]
# Extracting files...
# /users/linyx/.cache/kagglehub/datasets/dimensi0n/afhq-512/versions/1
